# %%
# %load_ext jupyter_black
# Out:
#                 <script type="application/javascript" id="jupyter_black">
#                 (function() {
#                     if (window.IPython === undefined) {
#                         return
#                     }
#                     var msg = "WARNING: it looks like you might have loaded " +
#                         "jupyter_black in a non-lab notebook with " +
#                         "`is_lab=True`. Please double check, and if " +
#                         "loading with `%load_ext` please review the README!"
#                     console.log(msg)
#                     alert(msg)
#                 })()
#                 </script>

# %%
import json
from pathlib import Path
from typing import Iterator
from urllib.error import HTTPError

import pandas as pd
import geopandas as gpd
from requests import Session, Response

# %%
baseurl = "https://mtarchive.geol.iastate.edu"


def iterurls(res: Response) -> Iterator[str]:
    """generator function that yields a list of json files"""
    yield from res.url + (
        pd.read_html(
            res.content,
            skiprows=[0, 1],
            parse_dates=["Unnamed: 2"],
        )[0]
        .set_index("Unnamed: 2")["Parent Directory"]
        .dropna()
    )


def feature_generator(features: list, valid_time: pd.Timestamp):
    for feat in features:
        props = feat["properties"]
        props["validTime"] = valid_time
        props["geometry"] = feat["geometry"]
        yield props


def get_data(
    start: str, end: str, save_to: Path = Path("/home/leaver2000/sppp/data")
) -> None:
    date_range = pd.date_range(start, end)
    date_nodes = baseurl + date_range.strftime("/%Y/%m/%d/mrms/ncep/ProbSevere/")
    with Session() as session:
        for valid_time, date_node in zip(date_range, date_nodes):
            try:
                r = session.get(date_node)
                r.raise_for_status()
                for fileurl in iterurls(r):
                    r = session.get(fileurl)
                    r.raise_for_status()
                    features = r.json()["features"]

                    df = pd.DataFrame(
                        feature_generator(features, valid_time)
                    ).set_index(["validTime", "ID"])
                    r.url.split("/")[-1][:-4]
                    local_file = save_to / f'{r.url.split("/")[-1][:-4]}.csv'
                    df.to_csv(local_file)


            except HTTPError:
                ...

if __name__ == "__main__":
    get_data("2022-06-01", "2022-06-02")
# Out:
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_000000.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_000200.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_000400.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_000600.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_000800.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_001000.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_001200.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_001400.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_001600.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_001800.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_002000.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_002200.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_002400.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_002600.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_002800.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_003000.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_003200.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_003400.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_003600.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_003800.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_004000.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_004200.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_004400.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_004600.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_004800.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_005000.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_005200.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_005400.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_005600.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_005800.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_010000.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_010200.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_010400.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_010600.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_010800.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_011000.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_011200.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_011400.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_011600.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_011800.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_012000.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_012200.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_012400.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_012600.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_012800.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_013000.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_013200.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_013400.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_013600.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_013800.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_014000.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_014200.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_014400.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_014600.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_014800.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_015000.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_015200.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_015400.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_015600.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_015800.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_020000.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_020200.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_020400.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_020600.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_020800.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_021000.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_021200.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_021400.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_021600.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_021800.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_022000.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_022200.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_022400.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_022600.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_022800.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_023000.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_023200.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_023400.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_023600.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_023800.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_024000.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_024200.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_024400.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_024600.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_024800.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_025000.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_025200.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_025400.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_025600.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_025800.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_030000.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_030200.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_030400.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_030600.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_030800.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_031000.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_031200.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_031400.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_031600.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_031800.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_032000.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_032200.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_032400.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_032600.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_032800.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_033000.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_033200.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_033400.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_033600.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_033800.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_034000.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_034200.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_034400.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_034600.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_034800.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_035000.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_035200.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_035400.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_035600.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_035800.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_040000.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_040200.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_040400.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_040600.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_040800.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_041000.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_041200.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_041400.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_041600.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_041800.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_042000.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_042200.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_042400.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_042600.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_042800.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_043000.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_043200.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_043400.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_043600.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_043800.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_044000.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_044200.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_044400.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_044600.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_044800.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_045000.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_045200.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_045400.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_045600.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_045800.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_050000.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_050200.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_050400.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_050600.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_050800.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_051000.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_051200.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_051400.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_051600.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_051800.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_052000.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_052200.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_052400.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_052600.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_052800.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_053000.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_053200.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_053400.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_053600.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_053800.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_054000.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_054200.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_054400.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_054600.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_054800.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_055000.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_055200.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_055400.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_055600.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_055800.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_060000.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_060200.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_060400.json
# https://mtarchive.geol.iastate.edu/2022/06/01/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_20220601_060600.json
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_16304/2809705143.py in <cell line: 57>()
#      55
#      56
# ---> 57 get_data("2022-06-01", "2022-06-02")
#
# /tmp/ipykernel_16304/2809705143.py in get_data(start, end, save_to)
#      35                 for fileurl in iterurls(r):
#      36                     print(fileurl)
# ---> 37                     r = session.get(fileurl)
#      38                     r.raise_for_status()
#      39                     # response.raise_for_status()
#
# ~/venv/lib/python3.10/site-packages/requests/sessions.py in get(self, url, **kwargs)
#     598
#     599         kwargs.setdefault("allow_redirects", True)
# --> 600         return self.request("GET", url, **kwargs)
#     601
#     602     def options(self, url, **kwargs):
#
# ~/venv/lib/python3.10/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     585         }
#     586         send_kwargs.update(settings)
# --> 587         resp = self.send(prep, **send_kwargs)
#     588
#     589         return resp
#
# ~/venv/lib/python3.10/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     743
#     744         if not stream:
# --> 745             r.content
#     746
#     747         return r
#
# ~/venv/lib/python3.10/site-packages/requests/models.py in content(self)
#     897                 self._content = None
#     898             else:
# --> 899                 self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     900
#     901         self._content_consumed = True
#
# ~/venv/lib/python3.10/site-packages/requests/models.py in generate()
#     814             if hasattr(self.raw, "stream"):
#     815                 try:
# --> 816                     yield from self.raw.stream(chunk_size, decode_content=True)
#     817                 except ProtocolError as e:
#     818                     raise ChunkedEncodingError(e)
#
# ~/venv/lib/python3.10/site-packages/urllib3/response.py in stream(self, amt, decode_content)
#     577         else:
#     578             while not is_fp_closed(self._fp):
# --> 579                 data = self.read(amt=amt, decode_content=decode_content)
#     580
#     581                 if data:
#
# ~/venv/lib/python3.10/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     520             else:
#     521                 cache_content = False
# --> 522                 data = self._fp.read(amt) if not fp_closed else b""
#     523                 if (
#     524                     amt != 0 and not data
#
# /usr/lib/python3.10/http/client.py in read(self, amt)
#     463                 # clip the read to the "end of response"
#     464                 amt = self.length
# --> 465             s = self.fp.read(amt)
#     466             if not s and amt:
#     467                 # Ideally, we would raise IncompleteRead if the content-length
#
# /usr/lib/python3.10/socket.py in readinto(self, b)
#     703         while True:
#     704             try:
# --> 705                 return self._sock.recv_into(b)
#     706             except timeout:
#     707                 self._timeout_occurred = True
#
# /usr/lib/python3.10/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1271                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1272                   self.__class__)
# -> 1273             return self.read(nbytes, buffer)
#    1274         else:
#    1275             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.10/ssl.py in read(self, len, buffer)
#    1127         try:
#    1128             if buffer is not None:
# -> 1129                 return self._sslobj.read(len, buffer)
#    1130             else:
#    1131                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
from pathlib import Path
import pandas as pd
from requests import Session, HTTPError
from shutil import copyfileobj
import json

template  = "https://mtarchive.geol.iastate.edu/%Y/%m/%d/mrms/ncep/ProbSevere/MRMS_PROBSEVERE_%Y%m%d_%H%M00.json"
urls = pd.date_range(start="2022-05-01T00:00:00Z", end="2022-07-15T00:00:00Z", freq="2min").strftime(template)
outdir = Path("/home/leaver2000/sppp/archive")
# urls
with Session() as session:
    for url in urls:
        try:
            r = session.get(url, stream=True)
            r.raise_for_status()
            outfile = outdir /  r.url.split("/")[-1]

            with outfile.open("w") as f:
                json.dump(r.json(), f, indent=4)

                
        except ConnectionError:
            print("error downloading", url)
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# /usr/lib/python3/dist-packages/six.py in raise_from(value, from_value)
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#
# /usr/lib/python3.10/http/client.py in getresponse(self)
#    1373             try:
# -> 1374                 response.begin()
#    1375             except ConnectionError:
#
# /usr/lib/python3.10/http/client.py in begin(self)
#     317         while True:
# --> 318             version, status, reason = self._read_status()
#     319             if status != CONTINUE:
#
# /usr/lib/python3.10/http/client.py in _read_status(self)
#     286             # sending a valid response.
# --> 287             raise RemoteDisconnected("Remote end closed connection without"
#     288                                      " response")
#
# RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# /usr/lib/python3/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     754
# --> 755             retries = retries.increment(
#     756                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# /usr/lib/python3/dist-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     531             if read is False or not self._is_method_retryable(method):
# --> 532                 raise six.reraise(type(error), error, _stacktrace)
#     533             elif read is not None:
#
# /usr/lib/python3/dist-packages/six.py in reraise(tp, value, tb)
#     717             if value.__traceback__ is not tb:
# --> 718                 raise value.with_traceback(tb)
#     719             raise value
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# /usr/lib/python3/dist-packages/six.py in raise_from(value, from_value)
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#
# /usr/lib/python3.10/http/client.py in getresponse(self)
#    1373             try:
# -> 1374                 response.begin()
#    1375             except ConnectionError:
#
# /usr/lib/python3.10/http/client.py in begin(self)
#     317         while True:
# --> 318             version, status, reason = self._read_status()
#     319             if status != CONTINUE:
#
# /usr/lib/python3.10/http/client.py in _read_status(self)
#     286             # sending a valid response.
# --> 287             raise RemoteDisconnected("Remote end closed connection without"
#     288                                      " response")
#
# ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# /tmp/ipykernel_2986/3349225431.py in <cell line: 11>()
#      12     for url in urls:
#      13         try:
# ---> 14             r = session.get(url, stream=True)
#      15             r.raise_for_status()
#      16             outfile = outdir /  r.url.split("/")[-1]
#
# /usr/lib/python3/dist-packages/requests/sessions.py in get(self, url, **kwargs)
#     553
#     554         kwargs.setdefault('allow_redirects', True)
# --> 555         return self.request('GET', url, **kwargs)
#     556
#     557     def options(self, url, **kwargs):
#
# /usr/lib/python3/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# /usr/lib/python3/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# /usr/lib/python3/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     496
#     497         except (ProtocolError, socket.error) as err:
# --> 498             raise ConnectionError(err, request=request)
#     499
#     500         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
