# %%
from sppp.transfer import to_midf

# %%
df = to_midf("/workspaces/sppp/data/2022/**/*.json")
df
# Out:
# /opt/venv/lib/python3.10/site-packages/geopandas/geodataframe.py:1455: UserWarning: Geometry column does not contain geometry.
#   warnings.warn("Geometry column does not contain geometry.")
#                                                                      geometry  \
# validTime           ID
# 2022-07-20 10:12:39 360483  [(-84.86, 36.23), (-84.83, 36.23), (-84.8, 36....
#                     360507  [(-83.38, 33.9), (-83.35, 33.9), (-83.34, 33.8...
#                     360611  [(-85.88, 37.17), (-85.84, 37.17), (-85.82, 37...
#                     360845  [(-78.03, 45.45), (-78.0, 45.45), (-78.0, 45.4...
#                     360923  [(-98.74, 35.52), (-98.71, 35.52), (-98.68, 35...
# ...                                                                       ...
# 2022-07-20 01:46:39 358602  [(-109.32, 30.84), (-109.28, 30.84), (-109.27,...
#                     358603  [(-110.02, 30.74), (-109.98, 30.74), (-109.97,...
# ...

# %%
import pandas as pd
path = "../data/2022-07.parquet"
df = pd.read_parquet(path)
df
# Out:
#                                                                      geometry  \
# validTime           ID
# 2022-07-20 10:12:39 360483  [[-84.86, 36.23], [-84.83, 36.23], [-84.8, 36....
#                     360507  [[-83.38, 33.9], [-83.35, 33.9], [-83.34, 33.8...
#                     360611  [[-85.88, 37.17], [-85.84, 37.17], [-85.82, 37...
#                     360845  [[-78.03, 45.45], [-78.0, 45.45], [-78.0, 45.4...
#                     360923  [[-98.74, 35.52], [-98.71, 35.52], [-98.68, 35...
# ...                                                                       ...
# 2022-07-20 01:46:39 358602  [[-109.32, 30.84], [-109.28, 30.84], [-109.27,...
#                     358603  [[-110.02, 30.74], [-109.98, 30.74], [-109.97,...
#                     358604  [[-85.58, 30.12], [-85.57, 30.11], [-85.51, 30...
#                     358605  [[-85.52, 29.43], [-85.45, 29.43], [-85.45, 29...
#                     358606  [[-83.49, 29.15], [-83.47, 29.14], [-83.48, 29...
#
# ...

# %%
idx = pd.IndexSlice
df.loc[df["PS"] > 90,:].index.unique("ID")
# from geopandas import GeoDataFrame
# df["geometry"].explode()
# GeoDataFrame(geometry=df["geometry"].explode())
# df.loc[idx[:,"365855"],:]
# Out:
# Index(['365855', '357552', '366703', '357536', '358064', '358192', '359452',
#        '357877', '358411', '359450', '358092', '358032', '358782', '359169',
#        '367316', '366548', '367657', '357278', '359342', '359420', '359523',
#        '368722', '358816', '369187', '364627', '358768', '358776', '365377',
#        '360325', '367183', '359352', '369671', '359105', '369868'],
#       dtype='object', name='ID')
